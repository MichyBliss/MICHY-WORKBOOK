# %% [markdown]
# <a href="https://colab.research.google.com/github/MichyBliss/MICHY-WORKBOOK/blob/main/CAR_SALES_WORKBOOK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Copy of Car_sales.csv')

# %%
df.head(10)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
# 6         Audi       A8               1.380               39.000    Passenger
# 7          BMW     323i              19.747                  NaN    Passenger
# 8          BMW     328i               9.231               28.675    Passenger
# 9          BMW     528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
df .tail()
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 152        Volvo   V40               3.545                  NaN    Passenger
# 153        Volvo   S70              15.245                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 152                24.4          1.9       160.0      100.5   67.6   176.6
# 153                27.5          2.4       168.0      104.9   69.3   185.9
# 154                28.8          2.4       168.0      104.9   69.3   186.2
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
# ...

# %%
df.shape
# Out:
# (157, 16)

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
df['Price_in_thousands'].dtype
# Out:
# dtype('float64')

# %%
#Are there any missing values in the dataset? If so, how many and in which columns?
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %% [markdown]
# Fill the missing values in the year_resale_value with the average year_resale_value, then drop all other rows with missing values in the dataset

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
# # Calculate the mean of the '__year_resale_value' column
# mean_value = df['__year_resale_value'].mean()
#
# # Fill missing values in the '__year_resale_value' column with the mean
# df['__year_resale_value'].fillna(mean_value, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     2
# Engine_size            1
# Horsepower             1
# Wheelbase              1
# Width                  1
# Length                 1
# Curb_weight            2
# Fuel_capacity          1
# Fuel_efficiency        3
# Latest_Launch          0
# Power_perf_factor      2
# dtype: int64

# %%
# Clean the name of the __year_resale_value column by removing the leading underscore
df.rename(columns={'__year_resale_value': 'year_resale_value'}, inplace=True)

# %%
# Do descriptive statistics (mean, median, standard deviation) of the numerical columns. What do you notice? or i will use df.describe


# Compute mean
mean_values = df.mean(numeric_only=True)

# Compute median
median_values = df.median(numeric_only=True)

# Compute standard deviation
std_values = df.std(numeric_only=True)

# Combine into one DataFrame for clarity
summary_stats = pd.DataFrame({
    'Mean': mean_values,
    'Median': median_values,
    'Standard Deviation': std_values
})

print(summary_stats)
# Out:
#                           Mean      Median  Standard Deviation
# Sales_in_thousands   52.998076   29.450000           68.029422
# year_resale_value    18.072975   17.710000           10.045282
# Price_in_thousands   27.390755   22.799000           14.351653
# Engine_size           3.060897    3.000000            1.044653
# Horsepower          185.948718  177.500000           56.700321
# Wheelbase           107.487179  107.000000            7.641303
# Width                71.150000   70.550000            3.451872
# Length              187.343590  187.900000           13.431754
# Curb_weight           3.378026    3.342000            0.630502
# Fuel_capacity        17.951923   17.200000            3.887921
# Fuel_efficiency      23.844156   24.000000            4.282706
# Power_perf_factor    77.043591   72.030917           25.142664

# %%
# Check if the dataset has any duplicates. If there are, drop them
duplicates = df.duplicated()
print(f"Number of duplicate rows: {duplicates.sum()}")
# Out:
# Number of duplicate rows: 0

# %%
# Find out the most common car brand in the dataset using `value_counts()`
df['Manufacturer'].value_counts()
# Out:
# Manufacturer
# Ford          11
# Dodge         11
# Chevrolet      9
# Mercedes-B     9
# Toyota         9
# Chrysler       7
# Mitsubishi     7
# Nissan         7
# Mercury        6
# Oldsmobile     6
# Lexus          6
# Pontiac        6
# Volvo          6
# Volkswagen     6
# Cadillac       5
# Honda          5
# Saturn         5
# Plymouth       4
# Buick          4
# Acura          4
# Audi           3
# BMW            3
# Lincoln        3
# Porsche        3
# Jeep           3
# Hyundai        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: count, dtype: int64

# %%
# Which manufacturer has the highest and lowest average sales volume?
manufacturer_sales = df.groupby('Manufacturer')['Sales_in_thousands'].mean()
manufacturer_sales

sorted_sales = manufacturer_sales.sort_values(ascending=False)
print(sorted_sales)
# Out:
# Manufacturer
# Ford          183.875909
# Honda         118.534800
# Jeep           97.717667
# Dodge          82.740818
# Toyota         82.245000
# Pontiac        61.755667
# Chevrolet      61.596111
# Buick          60.504750
# Nissan         57.090714
# Hyundai        45.775333
# Subaru         40.067500
# Mercury        39.666500
# Volkswagen     34.868667
# Saturn         33.770000
# Oldsmobile     29.831500
# Chrysler       28.817286
# Lincoln        28.544667
# Mitsubishi     25.842143
# Infiniti       23.713000
# Cadillac       22.435600
# Acura          19.751250
# Lexus          17.807167
# Plymouth       16.000250
# BMW            15.501667
# Jaguar         15.467000
# Audi           13.519000
# Mercedes-B     13.013889
# Volvo          12.623333
# Saab           10.653000
# Porsche         4.042667
# Name: Sales_in_thousands, dtype: float64

# %%
# What is the distribution of car prices in the dataset?
plt.figure(figsize=(8, 6))
sns.histplot(df['Price_in_thousands'], bins=20, kde=True)
plt.title('Distribution of Car Prices')
plt.xlabel('Manufacturer')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Plot a correlation matrix to see if different numerical variables in the dataset correlate with each other
corr_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title("Correlation Matrix of Numerical Variables")
plt.show()

# %% [markdown]
# the red line shows a positive correlation with +1
# the light blue shows no bositive corroleation

# %%
# Plot a histogram of the car prices using Matplotlib
plt.figure(figsize=(8, 6))
plt.hist(df['Price_in_thousands'], bins=20, edgecolor='k')
plt.title('Distribution of Car Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Convert a column to datetime
df['Latest_Launch'] = pd.to_datetime(df['Latest_Launch'])

# %%
# Plot the relationship between price and latest launch year.
plt.figure(figsize=(10, 6))
sns.lineplot(data = df, x='Latest_Launch', y='Price_in_thousands', marker='o')
plt.title('Average Car Price by Latest Launch Year')
plt.xlabel('Latest_Launch')
plt.ylabel('Price_in_thousands')
plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor',
#        'Resale_Value_Percentage'],
#       dtype='object')

# %%
# Group cars by manufacturers and analyze their average price and fuel efficiency
manufacturer_stats = df.groupby('Manufacturer').agg({
    'Price_in_thousands': 'mean',
    'Fuel_efficiency': 'mean'
})
manufacturer_stats
# Out:
#               Price_in_thousands  Fuel_efficiency
# Manufacturer
# Acura                  30.633333        25.250000
# Audi                   39.980000        23.333333
# BMW                    33.096667        25.000000
# Buick                  26.781250        24.250000
# Cadillac               40.254000        20.600000
# Chevrolet              20.022778        28.444444
# Chrysler               23.430833        24.500000
# Dodge                  24.213636        20.100000
# Ford                   21.047273        22.818182
# Honda                  20.277000        25.000000
# Hyundai                12.165667        27.666667
# Infiniti               29.465000        25.000000
# Jaguar                 42.800000        21.000000
# Jeep                   20.991667        18.666667
# Lexus                  44.055000        20.833333
# Lincoln                41.690000        19.333333
# Mercedes-B             52.916667        23.444444
# ...

# %%
# Can you identify and visualize the most popular car brands?
popular_brands = df['Manufacturer'].value_counts().head(10)
popular_brands
# Out:
# Manufacturer
# Ford          11
# Dodge         11
# Chevrolet      9
# Mercedes-B     9
# Toyota         9
# Chrysler       7
# Mitsubishi     7
# Nissan         7
# Mercury        6
# Oldsmobile     6
# Name: count, dtype: int64

# %%
# Which car model has the highest resale value compared to its initial price?
#Calculate the highest resale value in percentage
df['Resale_Value_Percentage'] = (df['year_resale_value'] / df['Price_in_thousands']) * 100

# Find the row with the highest resale value percentage
top_car = df.loc[df['Resale_Value_Percentage'].idxmax()]

# Display Model, Manufacturer, and Resale Percentage
print("Car with Highest Resale Value:")
print(f"Manufacturer: {top_car['Manufacturer']}")
print(f"Model: {top_car['Model']}")
print(f"Resale Value Percentage: {top_car['Resale_Value_Percentage']:.2f}%")
# Out:
# Car with Highest Resale Value:
# Manufacturer: Ford
# Model: Focus
# Resale Value Percentage: 146.76%

# %%
# Find the top 3 fuel-efficient cars with an engine size above 2.5 liters.
top_fuel_efficient_cars = df[df['Engine_size'] > 2.5].nlargest(3, 'Fuel_efficiency')
top_fuel_efficient_cars
# Out:
#    Manufacturer        Model  Sales_in_thousands  year_resale_value  \
# 22    Chevrolet  Monte Carlo              42.593          11.525000
# 27    Chevrolet       Impala             107.995          18.072975
# 2         Acura           CL              14.114          18.225000
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 22    Passenger               19.39          3.4       180.0      110.5
# 27    Passenger               18.89          3.4       180.0      110.5
# 2     Passenger                 NaN          3.2       225.0      106.9
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 22   72.7   197.9        3.340           17.0             27.0    12/22/2011
# 27   73.0   200.0        3.389           17.0             27.0     6/18/2011
# 2    70.6   192.0        3.470           17.2             26.0      1/4/2012
#
#     Power_perf_factor
# 22          72.030917
# 27          71.838039
# ...

# %%
# Which Lexus model has the highest horsepower?

lexus_cars = df[df['Manufacturer'] == 'Lexus']
highest_hp_lexus = lexus_cars.loc[lexus_cars['Horsepower'].idxmax()]
highest_hp_lexus
# Out:
# Manufacturer               Lexus
# Model                      GS400
# Sales_in_thousands         3.334
# year_resale_value      18.072975
# Vehicle_type           Passenger
# Price_in_thousands        46.305
# Engine_size                  4.0
# Horsepower                 300.0
# Wheelbase                  110.2
# Width                       70.9
# Length                     189.2
# Curb_weight                3.693
# Fuel_capacity               19.8
# Fuel_efficiency             21.0
# Latest_Launch         11/28/2012
# Power_perf_factor     125.013357
# Name: 72, dtype: object
